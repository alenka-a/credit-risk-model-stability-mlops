# %%
import numpy as np
import pandas as pd

import lightgbm as lgb
from sklearn.model_selection import train_test_split, GroupShuffleSplit, StratifiedGroupKFold

from numpy.typing import ArrayLike
from typing import Callable, Any

from sklearn.metrics import accuracy_score, roc_auc_score, precision_score, \
    recall_score, f1_score, confusion_matrix, ConfusionMatrixDisplay
from sklearn.base import BaseEstimator

import optuna
from optuna.visualization.matplotlib import plot_param_importances
from optuna.visualization import plot_optimization_history

import matplotlib.pyplot as plt

import yaml
import joblib

import warnings
warnings.filterwarnings('ignore')

# %%
config_path = '../config/params.yml'
config = yaml.load(open(config_path), Loader=yaml.FullLoader)

preproc_config = config['preprocessing']
training_config = config['train']
prediction_config = config['prediction']

# %% [markdown]
# # Preprocessig data

# %%
df_test = pd.read_parquet(prediction_config["predict_path"])
df_test.head()
# Out:
#    case_id  WEEK_NUM  actualdpdtolerance_344P  amtinstpaidbefduel24m_4187115A  \
# 0    57552       100                        0                        183992.0
# 1    57633       100                        0                             NaN
# 2    57569       100                        0                             0.0
# 3    57634       100                        0                         39948.8
# 4    57630       100                        0                             0.0
#
#    annuity_780A  annuitynextmonth_57A  applications30d_658L  \
# 0     6298.8003               12155.4                     0
# 1     8273.0000                   0.0                     0
# 2     4682.6000                   0.0                     1
# 3     1165.8000                   0.0                     0
# 4     8905.0000                   0.0                     0
#
#    applicationscnt_1086L  applicationscnt_464L  applicationscnt_629L  ...  \
# 0                      0                     0                     0  ...
# 1                      0                     0                     0  ...
# 2                      0                     0                     0  ...
# 3                      0                     0                     0  ...
# 4                      0                     0                     0  ...
#
#    mode_collaterals_typeofguarante_669M  mean_pmts_dpd_1073P  \
# 0                                  None                 <NA>
# 1                              c7a5ad39                    0
# 2                              a55475b1                 <NA>
# 3                                  None                 <NA>
# 4                              a55475b1                    0
#
#    mean_pmts_dpd_303P  mean_pmts_overdue_1140A  mean_pmts_overdue_1152A  \
# 0                <NA>                      NaN                      NaN
# 1                   0                      0.0                    0.000
# 2                2328                      NaN                33346.402
# 3                <NA>                      NaN                      NaN
# 4                   0                      0.0                    0.000
#
#    max_pmts_year_1139T  max_pmts_year_507T  mode_subjectroles_name_541M  \
# 0                 <NA>                <NA>                         None
# 1                    1                   1                     ab3c25cf
# 2                 <NA>                   2                     a55475b1
# 3                 <NA>                <NA>                         None
# 4                    0                   6                     a55475b1
#
#    month_decision  weekday_decision
# 0              11                 5
# 1               1                 2
# 2              12                 1
# 3               1                 3
# 4               3                 2
#
# [5 rows x 321 columns]

# %%
def get_bins(data: (int, float), first_val: (int, float),
             second_val: (int, float)) -> str:
    """
    Генерация бинов для разных признаков
    :param data: числовое значение
    :param first_val: первый порог значения для разбиения на бины
    :param second_val: второй порог значения для разбиения на бины
    :return: наименование бина
    """
    assert isinstance(data, (int, float)), "Проблема с типом данных в признаке"
    result = ("small" if data <= first_val else
              "medium" if first_val < data <= second_val else "large")
    return result


def fill_nans(df_data: pd.DataFrame, value: Any,
              columns: list[str]) -> pd.DataFrame:
    """
    Заполняет пропуски переданным значением
    :param df_data: датасет
    :param value: значение, которым необходимо заполнить пропуску
    :param columns: список признаков
    :return: датасет
    """
    for column in columns:
        if np.mean(df_data[column].isnull()) > 0:
            df_data[column] = df_data[column].fillna(value)
    return df_data


def merge_columns(df_data: pd.DataFrame, main_column: str, add_column: str,
                  new_column: str) -> pd.DataFrame:
    """
    Объединение двух дублирующихся признаков в один.
    Если значение в main_column заполнено то берется это значение, 
    иначе берется значение из add_column
    :param df_data: датасет
    :param main_column: основная признак
    :param add_column: дополнительный признак
    :param new_column: название нового признака
    :return: датасет
    """
    df_data[new_column] = df_data.apply(
        lambda x: x[add_column]
        if pd.isnull(x[main_column]) else x[main_column],
        axis=1).astype(df_data[main_column].dtype)

    df_data = df_data.drop([main_column, add_column], axis=1)
    return df_data


def replace_rare_values(df_data: pd.DataFrame,
                        columns: dict,
                        value: Any = "Other",
                        debug: bool = False):
    """
    Замена редко встречающихся значений 
    :param df_data: датасет
    :param columns: словарь, где key - имя столбца, 
                    value - порог, при котором заменяется значение столбца, 
                    если его частота ниже
    :param value: новое значение    
    :param debug: признак логирования дополнительной информации 
    :return: датасет
    """
    for column in columns.keys():
        nunique = df_data[column].nunique()
        rare_values = df_data[column].value_counts(
            dropna=True, normalize=True)[df_data[column].value_counts(
                dropna=True, normalize=True) < columns[column]].index

        df_data[column] = df_data[column].apply(lambda x: "Other"
                                                if x in rare_values else x)

        if debug:
            print(
                f"{column} reduced nunique from {nunique} to {df_data[column].nunique()}"
            )
    return df_data


def replace_values_evaluate(df_data: pd.DataFrame,
                            columns: str,
                            unique_values_path: str,
                            value: Any = "Other"):
    """
    Замена значений, которые были заменены в train
    :param df_data: датасет
    :param columns: список столбцов
    :param unique_values_path: путь до списока с признаками train
    :param value: новое значение    
    :return: датасет
    """
    with open(unique_values_path) as json_file:
        unique_values = json.load(json_file)

    for column in columns:
        train_values = unique_values[column]
        df_data[column] = df_data[column].apply(
            lambda x: x if x in train_values or pd.isnull(x) else "Other")
    return df_data


def drop_columns_by_corr_matrix(df_data: pd.DataFrame,
                                except_columns: list[str],
                                threshold: float = 0.9,
                                debug=False) -> pd.DataFrame:
    """
    Удаление сильно скоррелированных признаков
    :param df_data: датасет
    :param except_columns: исключаемые признаки
    :param threshold: порог, при котором признак удаляется
    :param debug: признак логирования дополнительной информации 
    :return: датасет
    """
    cor_matrix = df_data.drop(columns=except_columns,
                              axis=1).corr(method='spearman',
                                           numeric_only=True).abs()
    cor_matrix = cor_matrix.where(
        np.triu(np.ones(cor_matrix.shape), k=1).astype(bool))

    to_drop = [
        column for column in cor_matrix.columns
        if any(cor_matrix[column] > threshold)
    ]

    if debug:
        for column in to_drop:
            print(column)
            print(cor_matrix[column][cor_matrix[column] > threshold])
            print()
    return df_data.drop(to_drop, axis=1)


def transform_types(df_data: pd.DataFrame,
                    change_type_columns: dict) -> pd.DataFrame:
    """
    Преобразование признаков в заданный тип данных
    :param df_data: датасет
    :param change_type_columns: словарь с признаками и типами данных
    :return:
    """
    return df_data.astype(change_type_columns, errors="raise")


def save_unique_train_data(df_data: pd.DataFrame, drop_columns: list,
                           unique_values_path: str) -> None:
    """
    Сохранение словаря с признаками и уникальными значениями для категориальных переменных 
    и статистическими значениями для числовых переменных
    :param df_data: датасет
    :param drop_columns: список с признаками для удаления    
    :param unique_values_path: путь до файла со словарем
    :return: None
    """
    unique_df = df_data.drop(columns=drop_columns, axis=1, errors="ignore")

    category_columns = unique_df.select_dtypes(["object", "bool",
                                                "category"]).columns.to_list()
    dict_unique = {
        key:
        unique_df[key].unique().tolist()
        if key in category_columns else unique_df[key].describe().tolist()
        for key in unique_df.columns
    }

    with open(unique_values_path, "w") as file:
        json.dump(dict_unique, file)


def check_columns_evaluate(df_data: pd.DataFrame,
                           unique_values_path: str) -> pd.DataFrame:
    """
    Удаление признаков, которых нет в train, 
    проверка на наличие признаков из train 
    и упорядочивание признаков согласно train
    :param df_data: датасет test
    :param unique_values_path: путь до списока с признаками train для сравнения
    :return: датасет test
    """
    with open(unique_values_path) as json_file:
        unique_values = json.load(json_file)

    column_sequence = unique_values.keys()

    missing_features = set(column_sequence).difference(set(df_data.columns))

    assert not any(missing_features), f"Пропущены признаки: {missing_features}"
    return df_data[column_sequence]

# %%
def preprocess_data_pipeline(df_data: pd.DataFrame,
                             flg_evaluate: bool = True,
                             debug=False,
                             **kwargs):
    """
    Пайплайн по предобработке данных
    :param df_data: датасет
    :param flg_evaluate: флаг для evaluate
    :param debug: флаг для логирования дополнительной информации 
    :return: датасет
    """
    df_data = df_data.drop(kwargs['drop_columns'], axis=1, errors="ignore")

    except_columns = [kwargs["target_column"], kwargs["groups_column"]]

    # Merge columns
    map_merge_columns = kwargs["map_merge_columns"]
    if map_merge_columns:
        for key in map_merge_columns.keys():
            df_data = merge_columns(df_data,
                                    main_column=map_merge_columns[key][0],
                                    add_column=map_merge_columns[key][1],
                                    new_column=key)

    # Bins
    map_bins_columns = kwargs["map_bins_columns"]
    if map_bins_columns:
        for key in map_bins_columns.keys():
            df_data[f"{key}_bins"] = df_data[key].apply(lambda x: get_bins(
                x,
                first_val=map_bins_columns[key][0],
                second_val=map_bins_columns[key][1],
            ))

    map_replace_rare_values = kwargs["map_replace_rare_values"]
    unique_values_path = kwargs["unique_values_path"]

    if flg_evaluate:
        if map_replace_rare_values:
            df_data = replace_values_evaluate(
                df_data,
                map_replace_rare_values.keys(),
                unique_values_path=unique_values_path)

        df_data = check_columns_evaluate(df_data=df_data,
                                         unique_values_path=unique_values_path)

    else:
        if map_replace_rare_values:
            # Replace rare values
            df_data = replace_rare_values(df_data,
                                          map_replace_rare_values,
                                          debug=debug)

    # Fill nans
    cat_columns = df_data.select_dtypes("object").columns.to_list()
    numeric_columns = df_data.select_dtypes(
        exclude=["object", "bool", "category"]).columns.to_list()
    df_data = fill_nans(df_data, value="Unknown", columns=cat_columns)
    df_data = fill_nans(df_data, value=0, columns=numeric_columns)

    # To category
    category_maps = {
        key: "category"
        for key in df_data.select_dtypes(["object"]).columns
    }
    df_data = transform_types(df_data=df_data,
                              change_type_columns=category_maps)

    if not flg_evaluate:
        corr_matrix_settings = kwargs["corr_matrix_settings"]
        if corr_matrix_settings and corr_matrix_settings["enable"]:
            df_data = drop_columns_by_corr_matrix(
                df_data,
                except_columns=except_columns,
                threshold=corr_matrix_settings["threshold"],
                debug=debug)

        save_unique_train_data(
            df_data=df_data,
            drop_columns=except_columns,
            unique_values_path=unique_values_path,
        )

    return df_data

# %%
df_test
# Out:
#    case_id  WEEK_NUM  actualdpdtolerance_344P  amtinstpaidbefduel24m_4187115A  \
# 0    57552       100                        0                      183992.000
# 1    57633       100                        0                             NaN
# 2    57569       100                        0                           0.000
# 3    57634       100                        0                       39948.800
# 4    57630       100                        0                           0.000
# 5    57631       100                        0                             NaN
# 6    57549       100                        0                      129704.400
# 7    57551       100                        0                       71036.400
# 8    57543       100                        0                      191767.360
# 9    57632       100                        0                       63647.402
#
#    annuity_780A  annuitynextmonth_57A  applications30d_658L  \
# 0     6298.8003            12155.4000                     0
# 1     8273.0000                0.0000                     0
# 2     4682.6000                0.0000                     1
# 3     1165.8000                0.0000                     0
# 4     8905.0000                0.0000                     0
# 5     2540.6000                0.0000                     0
# 6     5742.6000             3546.6000                     2
# 7     2844.6000                0.0000                     1
# 8     3674.6000             1218.2001                     0
# 9     4732.0000                0.0000                     0
#
#    applicationscnt_1086L  applicationscnt_464L  applicationscnt_629L  ...  \
# 0                      0                     0                     0  ...
# 1                      0                     0                     0  ...
# 2                      0                     0                     0  ...
# 3                      0                     0                     0  ...
# 4                      0                     0                     0  ...
# 5                      0                     0                     0  ...
# 6                      0                     0                     0  ...
# 7                      0                     0                     0  ...
# 8                      0                     0                     0  ...
# 9                      0                     0                     0  ...
#
#    mode_collaterals_typeofguarante_669M  mean_pmts_dpd_1073P  \
# 0                                  None                 <NA>
# 1                              c7a5ad39                    0
# 2                              a55475b1                 <NA>
# 3                                  None                 <NA>
# 4                              a55475b1                    0
# 5                              a55475b1                    0
# 6                              a55475b1                 <NA>
# 7                              a55475b1                 <NA>
# 8                              a55475b1                    0
# 9                              a55475b1                    0
#
#    mean_pmts_dpd_303P  mean_pmts_overdue_1140A  mean_pmts_overdue_1152A  \
# 0                <NA>                      NaN                      NaN
# 1                   0                      0.0                    0.000
# 2                2328                      NaN                33346.402
# 3                <NA>                      NaN                      NaN
# 4                   0                      0.0                    0.000
# 5                   0                      0.0                    0.000
# 6                <NA>                      NaN                      NaN
# 7                <NA>                      NaN                      NaN
# 8                <NA>                      0.0                      NaN
# 9                <NA>                      0.0                      NaN
#
#    max_pmts_year_1139T  max_pmts_year_507T  mode_subjectroles_name_541M  \
# 0                 <NA>                <NA>                         None
# 1                    1                   1                     ab3c25cf
# 2                 <NA>                   2                     a55475b1
# 3                 <NA>                <NA>                         None
# 4                    0                   6                     a55475b1
# 5                    3                   4                     a55475b1
# 6                    0                   3                     ab3c25cf
# 7                    0                   3                     ab3c25cf
# 8                    0                   3                     ab3c25cf
# 9                    3                <NA>                     a55475b1
#
#    month_decision  weekday_decision
# 0              11                 5
# 1               1                 2
# 2              12                 1
# 3               1                 3
# 4               3                 2
# 5               6                 6
# 6               1                 1
# 7              11                 5
# 8               5                 5
# 9               2                 6
#
# [10 rows x 321 columns]

# %%
df_proc_test = preprocess_data_pipeline(df_test,
                                        flg_evaluate=True,
                                        **preproc_config)
df_proc_test
# Out:
#    actualdpdtolerance_344P  amtinstpaidbefduel24m_4187115A  annuity_780A  \
# 0                        0                      183992.000     6298.8003
# 1                        0                           0.000     8273.0000
# 2                        0                           0.000     4682.6000
# 3                        0                       39948.800     1165.8000
# 4                        0                           0.000     8905.0000
# 5                        0                           0.000     2540.6000
# 6                        0                      129704.400     5742.6000
# 7                        0                       71036.400     2844.6000
# 8                        0                      191767.360     3674.6000
# 9                        0                       63647.402     4732.0000
#
#    annuitynextmonth_57A  applications30d_658L  applicationscnt_1086L  \
# 0            12155.4000                     0                      0
# 1                0.0000                     0                      0
# 2                0.0000                     1                      0
# 3                0.0000                     0                      0
# 4                0.0000                     0                      0
# 5                0.0000                     0                      0
# 6             3546.6000                     2                      0
# 7                0.0000                     1                      0
# 8             1218.2001                     0                      0
# 9                0.0000                     0                      0
#
#    applicationscnt_464L  applicationscnt_629L  applicationscnt_867L  \
# 0                     0                     0                     9
# 1                     0                     0                     3
# 2                     0                     0                     6
# 3                     0                     0                     0
# 4                     0                     0                     1
# 5                     0                     0                     0
# 6                     0                     0                    10
# 7                     0                     0                     2
# 8                     0                     0                     9
# 9                     0                     0                     1
#
#    avgdbddpdlast24m_3658932P  ...  mode_collaterals_typeofguarante_669M  \
# 0                         -9  ...                               Unknown
# 1                          0  ...                              c7a5ad39
# 2                       2824  ...                              a55475b1
# 3                         -4  ...                               Unknown
# 4                          0  ...                              a55475b1
# 5                          0  ...                              a55475b1
# 6                          0  ...                              a55475b1
# 7                         -1  ...                              a55475b1
# 8                          1  ...                              a55475b1
# 9                         -7  ...                              a55475b1
#
#    mean_pmts_dpd_1073P  mean_pmts_dpd_303P  max_pmts_year_1139T  \
# 0                    0                   0                    0
# 1                    0                   0                    1
# 2                    0                2328                    0
# 3                    0                   0                    0
# 4                    0                   0                    0
# 5                    0                   0                    3
# 6                    0                   0                    0
# 7                    0                   0                    0
# 8                    0                   0                    0
# 9                    0                   0                    3
#
#    max_pmts_year_507T  mode_subjectroles_name_541M  month_decision  \
# 0                   0                      Unknown              11
# 1                   1                     ab3c25cf               1
# 2                   2                     a55475b1              12
# 3                   0                      Unknown               1
# 4                   6                     a55475b1               3
# 5                   4                     a55475b1               6
# 6                   3                     ab3c25cf               1
# 7                   3                     ab3c25cf              11
# 8                   3                     ab3c25cf               5
# 9                   0                     a55475b1               2
#
#    weekday_decision age  age_bins
# 0                 5  65     large
# 1                 2  28     small
# 2                 1  72     large
# 3                 3  44    medium
# 4                 2  54    medium
# 5                 6  35     small
# 6                 1  62     large
# 7                 5  38    medium
# 8                 5  40    medium
# 9                 6  63     large
#
# [10 rows x 243 columns]

# %% [markdown]
# Проверим на тренировочном датасете

# %%
df_train = pd.read_parquet(preproc_config["train_path"])
print(df_train.shape)
df_train[:5]
# Out:
# (100000, 322)
#    case_id  WEEK_NUM  target  actualdpdtolerance_344P  \
# 0   691811        19       0                     <NA>
# 1   822442        39       0                     <NA>
# 2   876101        47       0                     <NA>
# 3   945235        55       0                     <NA>
# 4  2591718        26       0                        0
#
#    amtinstpaidbefduel24m_4187115A  annuity_780A  annuitynextmonth_57A  \
# 0                             NaN    12544.8000                   0.0
# 1                             NaN     1895.6000                   0.0
# 2                             NaN     1768.0000                   0.0
# 3                             NaN     3010.6000                   0.0
# 4                        66877.71     3548.4001                2486.6
#
#    applications30d_658L  applicationscnt_1086L  applicationscnt_464L  ...  \
# 0                     0                      0                     0  ...
# 1                     0                      0                     0  ...
# 2                     0                      0                     0  ...
# 3                     0                      0                     0  ...
# 4                     0                      0                     0  ...
#
#    mode_collaterals_typeofguarante_669M  mean_pmts_dpd_1073P  \
# 0                              a55475b1                    0
# 1                              a55475b1                    0
# 2                              a55475b1                    0
# 3                                  None                 <NA>
# 4                              a55475b1                    0
#
#    mean_pmts_dpd_303P  mean_pmts_overdue_1140A  mean_pmts_overdue_1152A  \
# 0                <NA>                 0.000000                      NaN
# 1                   0                 0.000000                 0.000000
# 2                   0                 0.000000                22.896704
# 3                <NA>                      NaN                      NaN
# 4                   0               121.853437               249.097379
#
#    max_pmts_year_1139T  max_pmts_year_507T  mode_subjectroles_name_541M  \
# 0                   -1                <NA>                     a55475b1
# 1                   -1                   0                     a55475b1
# 2                   -1                   0                     a55475b1
# 3                 <NA>                <NA>                         None
# 4                   -1                  -1                     a55475b1
#
#    month_decision  weekday_decision
# 0               5                 6
# 1              10                 7
# 2              11                 4
# 3               1                 6
# 4               7                 2
#
# [5 rows x 322 columns]

# %%
df_proc_train = preprocess_data_pipeline(df_train, flg_evaluate=False, debug=True, **preproc_config)
print(df_proc_train.shape)
df_proc_train[:5]
# Out:
# lastapprcommoditycat_1041M reduced nunique from 37 to 18
# lastcancelreason_561M reduced nunique from 59 to 18
# lastrejectcommoditycat_161M reduced nunique from 36 to 15
# mode_cancelreason_3545846M reduced nunique from 47 to 12
# mode_classificationofcontr_400M reduced nunique from 44 to 13
# mode_contractst_964M reduced nunique from 9 to 4
# mode_financialinstitution_382M reduced nunique from 96 to 18
# mode_financialinstitution_591M reduced nunique from 13 to 3
# currdebt_22A
# annuitynextmonth_57A    0.919336
# Name: currdebt_22A, dtype: float64
#
# disbursedcredamount_1113A
# credamount_770A    0.908278
# Name: disbursedcredamount_1113A, dtype: float64
#
# interestrate_311L
# eir_270L    1.0
# Name: interestrate_311L, dtype: float64
#
# lastapprdate_640D
# lastactivateddate_801D    0.925234
# Name: lastapprdate_640D, dtype: float64
#
# maxdpdlast9m_1059P
# maxdpdlast12m_727P    0.924516
# Name: maxdpdlast9m_1059P, dtype: float64
#
# maxdpdtolerance_374P
# daysoverduetolerancedd_3976961L    0.929231
# Name: maxdpdtolerance_374P, dtype: float64
#
# maxinstallast24m_3658928A
# avginstallast24m_3658937A    0.969375
# Name: maxinstallast24m_3658928A, dtype: float64
#
# maxlnamtstart6m_4525199A
# avgpmtlast12m_4525200A    0.90894
# Name: maxlnamtstart6m_4525199A, dtype: float64
#
# maxoutstandbalancel12m_4187113A
# avgoutstandbalancel6m_4187114A    0.924697
# Name: maxoutstandbalancel12m_4187113A, dtype: float64
#
# numincomingpmts_3546848L
# monthsannuity_845L    0.986636
# Name: numincomingpmts_3546848L, dtype: float64
#
# numinstlallpaidearly3d_817L
# monthsannuity_845L          0.934469
# numincomingpmts_3546848L    0.927028
# Name: numinstlallpaidearly3d_817L, dtype: float64
#
# numinstls_657L
# annuitynextmonth_57A    0.953603
# currdebt_22A            0.914044
# Name: numinstls_657L, dtype: float64
#
# numinstlsallpaid_934L
# monthsannuity_845L             0.975036
# numincomingpmts_3546848L       0.973198
# numinstlallpaidearly3d_817L    0.961409
# Name: numinstlsallpaid_934L, dtype: float64
#
# numinstlswithoutdpd_562L
# monthsannuity_845L             0.974663
# numincomingpmts_3546848L       0.977709
# numinstlallpaidearly3d_817L    0.952813
# numinstlsallpaid_934L          0.991278
# Name: numinstlswithoutdpd_562L, dtype: float64
#
# numinstpaid_4499208L
# numinstmatpaidtearly2d_4499204L    0.968708
# Name: numinstpaid_4499208L, dtype: float64
#
# numinstpaidearly3d_3546850L
# monthsannuity_845L             0.931334
# numincomingpmts_3546848L       0.924193
# numinstlallpaidearly3d_817L    0.997620
# numinstlsallpaid_934L          0.959544
# numinstlswithoutdpd_562L       0.951189
# Name: numinstpaidearly3d_3546850L, dtype: float64
#
# numinstpaidearly3dest_4493216L
# numinstmatpaidtearly2d_4499204L    0.991656
# numinstpaid_4499208L               0.957153
# Name: numinstpaidearly3dest_4493216L, dtype: float64
#
# numinstpaidearly5dobd_4499205L
# numinstmatpaidtearly2d_4499204L    0.965013
# numinstpaid_4499208L               0.923783
# numinstpaidearly3dest_4493216L     0.977242
# Name: numinstpaidearly5dobd_4499205L, dtype: float64
#
# numinstpaidearly_338L
# numinstlallpaidearly3d_817L    0.975222
# numinstlsallpaid_934L          0.919442
# numinstlswithoutdpd_562L       0.912679
# numinstpaidearly3d_3546850L    0.976470
# Name: numinstpaidearly_338L, dtype: float64
#
# numinstpaidearlyest_4493214L
# numinstmatpaidtearly2d_4499204L    0.965013
# numinstpaid_4499208L               0.923783
# numinstpaidearly3dest_4493216L     0.977242
# numinstpaidearly5dobd_4499205L     1.000000
# Name: numinstpaidearlyest_4493214L, dtype: float64
#
# numinstpaidlate1d_3546852L
# maxdpdinstlnum_3546846P    0.941671
# maxdpdtolerance_374P       0.908479
# Name: numinstpaidlate1d_3546852L, dtype: float64
#
# numinstregularpaid_973L
# monthsannuity_845L             0.958351
# numincomingpmts_3546848L       0.957379
# numinstlallpaidearly3d_817L    0.905408
# numinstlsallpaid_934L          0.947470
# numinstlswithoutdpd_562L       0.947144
# numinstpaidearly3d_3546850L    0.902845
# Name: numinstregularpaid_973L, dtype: float64
#
# numinstregularpaidest_4493210L
# numinstmatpaidtearly2d_4499204L    0.968700
# numinstpaid_4499208L               0.999994
# numinstpaidearly3dest_4493216L     0.957151
# numinstpaidearly5dobd_4499205L     0.923784
# numinstpaidearlyest_4493214L       0.923784
# Name: numinstregularpaidest_4493210L, dtype: float64
#
# numinsttopaygr_769L
# annuitynextmonth_57A    0.934622
# currdebt_22A            0.949378
# numinstls_657L          0.958989
# Name: numinsttopaygr_769L, dtype: float64
#
# numinstunpaidmax_3546851L
# annuitynextmonth_57A    0.930412
# currdebt_22A            0.947071
# numinstls_657L          0.956373
# numinsttopaygr_769L     0.996062
# Name: numinstunpaidmax_3546851L, dtype: float64
#
# numinstunpaidmaxest_4493212L
# numinsttopaygrest_4493213L    0.995568
# Name: numinstunpaidmaxest_4493212L, dtype: float64
#
# pctinstlsallpaidlate1d_3546856L
# numinstpaidlate1d_3546852L    0.952574
# Name: pctinstlsallpaidlate1d_3546856L, dtype: float64
#
# pctinstlsallpaidlate4d_3546849L
# pctinstlsallpaidlat10d_839L    0.903642
# Name: pctinstlsallpaidlate4d_3546849L, dtype: float64
#
# pctinstlsallpaidlate6d_3546844L
# pctinstlsallpaidlat10d_839L        0.946484
# pctinstlsallpaidlate4d_3546849L    0.957559
# Name: pctinstlsallpaidlate6d_3546844L, dtype: float64
#
# sellerplacescnt_216L
# applicationscnt_867L    0.915279
# Name: sellerplacescnt_216L, dtype: float64
#
# sumoutstandtotal_3546847A
# annuitynextmonth_57A         0.911687
# currdebt_22A                 0.985622
# numinstls_657L               0.918782
# numinsttopaygr_769L          0.964037
# numinstunpaidmax_3546851L    0.962122
# Name: sumoutstandtotal_3546847A, dtype: float64
#
# sumoutstandtotalest_4493215A
# numinsttopaygrest_4493213L      0.967669
# numinstunpaidmaxest_4493212L    0.965558
# Name: sumoutstandtotalest_4493215A, dtype: float64
#
# totaldebt_9A
# annuitynextmonth_57A         0.919325
# currdebt_22A                 1.000000
# numinstls_657L               0.914047
# numinsttopaygr_769L          0.949372
# numinstunpaidmax_3546851L    0.947075
# sumoutstandtotal_3546847A    0.985623
# Name: totaldebt_9A, dtype: float64
#
# totalsettled_863A
# maxannuity_159A             0.920121
# maxdebt4_972A               0.900080
# monthsannuity_845L          0.942162
# numincomingpmts_3546848L    0.954367
# numinstlsallpaid_934L       0.941010
# numinstlswithoutdpd_562L    0.950638
# numinstregularpaid_973L     0.920054
# Name: totalsettled_863A, dtype: float64
#
# totinstallast1m_4525188A
# maxpmtlast3m_4525190A    0.905487
# Name: totinstallast1m_4525188A, dtype: float64
#
# days90_310L
# days120_123L    0.917454
# Name: days90_310L, dtype: float64
#
# numberofqueries_373L
# days360_512L    1.0
# Name: numberofqueries_373L, dtype: float64
#
# pmtaverage_4527227A
# assignmentdate_4527235D    0.997821
# Name: pmtaverage_4527227A, dtype: float64
#
# pmtcount_4527229L
# assignmentdate_4527235D    0.999288
# pmtaverage_4527227A        0.997102
# Name: pmtcount_4527229L, dtype: float64
#
# pmtssum_45A
# pmtscount_423L    0.975109
# Name: pmtssum_45A, dtype: float64
#
# max_approvaldate_319D
# lastactivateddate_801D    0.923174
# lastapprdate_640D         0.997980
# Name: max_approvaldate_319D, dtype: float64
#
# max_creationdate_885D
# lastapplicationdate_877D    1.0
# Name: max_creationdate_885D, dtype: float64
#
# mean_currdebt_94A
# annuitynextmonth_57A         0.901841
# currdebt_22A                 0.984925
# numinsttopaygr_769L          0.933612
# numinstunpaidmax_3546851L    0.931874
# sumoutstandtotal_3546847A    0.970596
# totaldebt_9A                 0.984919
# Name: mean_currdebt_94A, dtype: float64
#
# max_dateactivated_425D
# lastactivateddate_801D    0.997745
# lastapprdate_640D         0.923413
# max_approvaldate_319D     0.925398
# Name: max_dateactivated_425D, dtype: float64
#
# max_firstnonzeroinstldate_307D
# lastapplicationdate_877D    0.90411
# max_creationdate_885D       0.90411
# Name: max_firstnonzeroinstldate_307D, dtype: float64
#
# mean_outstandingdebt_522A
# annuitynextmonth_57A         0.904796
# currdebt_22A                 0.988645
# numinstls_657L               0.900413
# numinsttopaygr_769L          0.937923
# numinstunpaidmax_3546851L    0.936525
# sumoutstandtotal_3546847A    0.974352
# totaldebt_9A                 0.988645
# mean_currdebt_94A            0.998245
# Name: mean_outstandingdebt_522A, dtype: float64
#
# mean_tenor_203L
# mean_pmtnum_8L    1.0
# Name: mean_tenor_203L, dtype: float64
#
# max_recorddate_4527225D
# mean_amount_4527230A    0.944417
# Name: max_recorddate_4527225D, dtype: float64
#
# mean_pmtamount_36A
# pmtscount_423L    0.953927
# pmtssum_45A       0.992887
# Name: mean_pmtamount_36A, dtype: float64
#
# mean_contractsum_5085717L
# contractssum_5085716L    0.999879
# Name: mean_contractsum_5085717L, dtype: float64
#
# max_dateofrealrepmt_138D
# max_dateofcredstart_181D    0.902233
# Name: max_dateofrealrepmt_138D, dtype: float64
#
# mean_instlamount_768A
# mean_credlmt_935A    0.910601
# Name: mean_instlamount_768A, dtype: float64
#
# max_lastupdate_388D
# max_dateofrealrepmt_138D    0.972384
# Name: max_lastupdate_388D, dtype: float64
#
# mean_numberofoutstandinstls_59L
# mean_numberofinstls_320L    0.968539
# Name: mean_numberofoutstandinstls_59L, dtype: float64
#
# mean_numberofoverdueinstlmax_1151L
# mean_dpdmax_757P    0.939533
# Name: mean_numberofoverdueinstlmax_1151L, dtype: float64
#
# mean_numberofoverdueinstls_725L
# mean_debtoverdue_47A    0.998703
# Name: mean_numberofoverdueinstls_725L, dtype: float64
#
# mean_outstandingamount_362A
# mean_numberofinstls_320L           0.954018
# mean_numberofoutstandinstls_59L    0.971544
# Name: mean_outstandingamount_362A, dtype: float64
#
# mean_overdueamount_659A
# mean_debtoverdue_47A               0.999102
# mean_numberofoverdueinstls_725L    0.999655
# Name: mean_overdueamount_659A, dtype: float64
#
# mean_overdueamountmax2_14A
# mean_numberofoverdueinstlmax_1039L    0.964018
# Name: mean_overdueamountmax2_14A, dtype: float64
#
# mean_overdueamountmax2_398A
# mean_numberofoverdueinstlmax_1151L    0.95721
# Name: mean_overdueamountmax2_398A, dtype: float64
#
# max_overdueamountmax2date_1002D
# max_numberofoverdueinstlmaxdat_148D    0.94517
# Name: max_overdueamountmax2date_1002D, dtype: float64
#
# max_overdueamountmax2date_1142D
# max_numberofoverdueinstlmaxdat_641D    0.926211
# Name: max_overdueamountmax2date_1142D, dtype: float64
#
# mean_overdueamountmax_35A
# mean_numberofoverdueinstlmax_1151L    0.950134
# mean_overdueamountmax2_398A           0.986741
# Name: mean_overdueamountmax_35A, dtype: float64
#
# max_overdueamountmaxdatemonth_284T
# max_dpdmaxdatemonth_442T    0.952683
# Name: max_overdueamountmaxdatemonth_284T, dtype: float64
#
# max_overdueamountmaxdatemonth_365T
# max_dpdmaxdatemonth_89T    0.956328
# Name: max_overdueamountmaxdatemonth_365T, dtype: float64
#
# max_overdueamountmaxdateyear_2T
# max_dpdmaxdateyear_596T    0.954234
# Name: max_overdueamountmaxdateyear_2T, dtype: float64
#
# max_overdueamountmaxdateyear_994T
# max_dpdmaxdateyear_896T    0.956564
# Name: max_overdueamountmaxdateyear_994T, dtype: float64
#
# mean_residualamount_856A
# mean_credlmt_935A        0.934436
# mean_instlamount_768A    0.944728
# Name: mean_residualamount_856A, dtype: float64
#
# mean_totalamount_996A
# mean_numberofinstls_320L           0.964061
# mean_numberofoutstandinstls_59L    0.939939
# mean_outstandingamount_362A        0.979297
# Name: mean_totalamount_996A, dtype: float64
#
# mean_totaldebtoverduevalue_178A
# mean_debtoverdue_47A               0.999146
# mean_numberofoverdueinstls_725L    0.999607
# mean_overdueamount_659A            0.999972
# Name: mean_totaldebtoverduevalue_178A, dtype: float64
#
# mean_totaldebtoverduevalue_718A
# mean_overdueamount_31A    0.945079
# Name: mean_totaldebtoverduevalue_718A, dtype: float64
#
# mean_totaloutstanddebtvalue_39A
# mean_debtoutstand_525A    0.998922
# Name: mean_totaloutstanddebtvalue_39A, dtype: float64
#
# max_amount_416A
# last_amount_416A    0.977092
# Name: max_amount_416A, dtype: float64
#
# last_openingdate_313D
# max_openingdate_857D    0.991215
# Name: last_openingdate_313D, dtype: float64
#
# mean_pmts_overdue_1140A
# mean_overdueamountmax_155A    0.996534
# Name: mean_pmts_overdue_1140A, dtype: float64
#
# mean_pmts_overdue_1152A
# mean_numberofoverdueinstlmax_1151L    0.956949
# mean_overdueamountmax2_398A           0.979987
# mean_overdueamountmax_35A             0.992861
# Name: mean_pmts_overdue_1152A, dtype: float64
# (100000, 245)
#    WEEK_NUM  target  actualdpdtolerance_344P  amtinstpaidbefduel24m_4187115A  \
# 0        19       0                        0                            0.00
# 1        39       0                        0                            0.00
# 2        47       0                        0                            0.00
# 3        55       0                        0                            0.00
# 4        26       0                        0                        66877.71
#
#    annuity_780A  annuitynextmonth_57A  applications30d_658L  \
# 0    12544.8000                   0.0                     0
# 1     1895.6000                   0.0                     0
# 2     1768.0000                   0.0                     0
# 3     3010.6000                   0.0                     0
# 4     3548.4001                2486.6                     0
#
#    applicationscnt_1086L  applicationscnt_464L  applicationscnt_629L  ...  \
# 0                      0                     0                     0  ...
# 1                      0                     0                     0  ...
# 2                      0                     0                     0  ...
# 3                      0                     0                     0  ...
# 4                      0                     0                     0  ...
#
#    mode_collaterals_typeofguarante_669M  mean_pmts_dpd_1073P  \
# 0                              a55475b1                    0
# 1                              a55475b1                    0
# 2                              a55475b1                    0
# 3                               Unknown                    0
# 4                              a55475b1                    0
#
#    mean_pmts_dpd_303P  max_pmts_year_1139T  max_pmts_year_507T  \
# 0                   0                   -1                   0
# 1                   0                   -1                   0
# 2                   0                   -1                   0
# 3                   0                    0                   0
# 4                   0                   -1                  -1
#
#    mode_subjectroles_name_541M  month_decision  weekday_decision  age  \
# 0                     a55475b1               5                 6   22
# 1                     a55475b1              10                 7   32
# 2                     a55475b1              11                 4   34
# 3                      Unknown               1                 6   21
# 4                     a55475b1               7                 2   58
#
#    age_bins
# 0     small
# 1     small
# 2     small
# 3     small
# 4     large
#
# [5 rows x 245 columns]

# %% [markdown]
# # Prediction

# %%
model = joblib.load(training_config['model_path'])
df_proc_test['predict'] = model.predict(df_proc_test)

# %%
df_proc_test
# Out:
#    actualdpdtolerance_344P  amtinstpaidbefduel24m_4187115A  annuity_780A  \
# 0                        0                      183992.000     6298.8003
# 1                        0                           0.000     8273.0000
# 2                        0                           0.000     4682.6000
# 3                        0                       39948.800     1165.8000
# 4                        0                           0.000     8905.0000
# 5                        0                           0.000     2540.6000
# 6                        0                      129704.400     5742.6000
# 7                        0                       71036.400     2844.6000
# 8                        0                      191767.360     3674.6000
# 9                        0                       63647.402     4732.0000
#
#    annuitynextmonth_57A  applications30d_658L  applicationscnt_1086L  \
# 0            12155.4000                     0                      0
# 1                0.0000                     0                      0
# 2                0.0000                     1                      0
# 3                0.0000                     0                      0
# 4                0.0000                     0                      0
# 5                0.0000                     0                      0
# 6             3546.6000                     2                      0
# 7                0.0000                     1                      0
# 8             1218.2001                     0                      0
# 9                0.0000                     0                      0
#
#    applicationscnt_464L  applicationscnt_629L  applicationscnt_867L  \
# 0                     0                     0                     9
# 1                     0                     0                     3
# 2                     0                     0                     6
# 3                     0                     0                     0
# 4                     0                     0                     1
# 5                     0                     0                     0
# 6                     0                     0                    10
# 7                     0                     0                     2
# 8                     0                     0                     9
# 9                     0                     0                     1
#
#    avgdbddpdlast24m_3658932P  ...  mean_pmts_dpd_1073P  mean_pmts_dpd_303P  \
# 0                         -9  ...                    0                   0
# 1                          0  ...                    0                   0
# 2                       2824  ...                    0                2328
# 3                         -4  ...                    0                   0
# 4                          0  ...                    0                   0
# 5                          0  ...                    0                   0
# 6                          0  ...                    0                   0
# 7                         -1  ...                    0                   0
# 8                          1  ...                    0                   0
# 9                         -7  ...                    0                   0
#
#    max_pmts_year_1139T  max_pmts_year_507T  mode_subjectroles_name_541M  \
# 0                    0                   0                      Unknown
# 1                    1                   1                     ab3c25cf
# 2                    0                   2                     a55475b1
# 3                    0                   0                      Unknown
# 4                    0                   6                     a55475b1
# 5                    3                   4                     a55475b1
# 6                    0                   3                     ab3c25cf
# 7                    0                   3                     ab3c25cf
# 8                    0                   3                     ab3c25cf
# 9                    3                   0                     a55475b1
#
#    month_decision  weekday_decision  age age_bins  predict
# 0              11                 5   65    large        0
# 1               1                 2   28    small        0
# 2              12                 1   72    large        1
# 3               1                 3   44   medium        0
# 4               3                 2   54   medium        0
# 5               6                 6   35    small        0
# 6               1                 1   62    large        0
# 7              11                 5   38   medium        0
# 8               5                 5   40   medium        0
# 9               2                 6   63    large        0
#
# [10 rows x 244 columns]
